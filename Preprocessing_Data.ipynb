# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression
from nltk.stem import WordNetLemmatizer
from sklearn.cluster import KMeans
import nltk
from ast import literal_eval

nltk.download('wordnet') 
nltk.download('stopwords')

df = pd.read_csv('/content/IITGN_FACULTY.csv',converters={'Reasearch Interests':literal_eval}) 


NUM_CLUSTERS = 5

def preprocess(text):
    
    text = text.lower()
    words = text.split()
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    words = sorted(list(set(words)))
    text = ' '.join(words)
    return text



def find_synonyms(query):
  synonyms = set()
  for word in query.split():
      for syn in wordnet.synsets(word):
          for lemma in syn.lemmas():
              synonyms.add(lemma.name().replace('_', ' '))
  return list(synonyms)

def get_scholar_data(url):
  headers = {
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299'
  }
  res = requests.get(url, headers=headers)
  soup = BeautifulSoup(res.text, 'html.parser')
  publications = []
  for pub in soup.select('#gsc_a_b .gsc_a_tr'):
      try:
          title = pub.select('.gsc_a_at')[0].text.strip()
          venue = pub.select('.gsc_a_jc')[0].text.strip()
          year = int(pub.select('.gsc_a_y')[0].text.strip())
          if year >= (pd.datetime.now().year - 5):
              publications.append((title, venue, year))
      except:
          pass
  return publications

# Cluster professors based on research interests
vectorizer = TfidfVectorizer(preprocessor=preprocess)
vectorizer.fit(df['Reasearch Interests'].apply(lambda x: ' '.join(x)))

reg = LinearRegression()
X = vectorizer.transform(df['Reasearch Interests'].apply(lambda x: ' '.join(x)))
y = df['h_index']
reg.fit(X, y)

km = KMeans(n_clusters=NUM_CLUSTERS, random_state=42)
km.fit(X)

def search(query):

    query = preprocess(query)
    query_synonyms = find_synonyms(query)
    query_vec = vectorizer.transform([query] + query_synonyms)
    
    cluster = km.predict(query_vec)[0]
    
    
    df_cluster = df[km.labels_ == cluster]
    
    relevance = reg.predict(query_vec)[:]
    
    ranked=[]

    exact_match = False
    for idx, row in df_cluster.iterrows():
        professor_name = row['Faculty Name'].lower()
        if query in professor_name:
            exact_match = True
            ranked = [(row['Faculty Name'], row['Institution'],row['HomePage'], row['Scholar Url'], row['Image'])]
            break
    
    if exact_match:
      return ranked
    for idx, row in df_cluster.iterrows():
      if row['h_index'] == float('nan') or pd.isna(row['h_index']):
        continue
      research_interests = row['Reasearch Interests']
      research_interests_words = [word for interest in research_interests for word in interest.split()]
      query_words = query.split() + query_synonyms
      if not any(word in research_interests_words for word in query_words):
          continue
      
      h_index = row['h_index']
      i10_index = row['i10_index'] if not pd.isna(row['i10_index']) else 0
      scholar_url = row['Scholar Url']
      if pd.isna(scholar_url):
          continue
    
      try:
          publications = get_scholar_data(scholar_url)
      except:
          publications = []
    
      recent_activity = sum([int(pub[2] >= (pd.datetime.now().year - 5)) for pub in publications])
      rank = 0.5 * (h_index + i10_index) + 0.3 * relevance + 0.2 * recent_activity # weights based on importance
      ranked.append((row['Faculty Name'], row['Institution'], row['HomePage'], row['Scholar Url'], row['Image'], rank))

    ranked.sort(key=lambda x: max(x[5]), reverse=True)
    return ranked
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
search('deep learning')
# Out:
# [('Anirban Dasgupta',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/anirban',
#   'https://scholar.google.co.in/citations?user=plJC8R0AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/anirban/729890348-1679554159/anirban.jpg',
#   array([48.11037414, 47.05727177, 47.05727177, 47.05727177, 47.92891329,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.74631956, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 46.82239739, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177])),
#  ('Ravi Hegde',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/ee/fac-ravi',
#   'https://scholar.google.co.in/citations?user=aHWM-b8AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/ee/fac-ravi/2150411337-1679554160/ravi.JPG',
#   array([28.61037414, 27.55727177, 27.55727177, 27.55727177, 28.42891329,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 28.24631956, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.32239739, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177])),
#  ('Nipun Batra',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/nipun',
#   'https://scholar.google.co.in/citations?user=rFGzHlIAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/nipun/3587009419-1679554159/nipun.jpg',
#   array([25.61037414, 24.55727177, 24.55727177, 24.55727177, 25.42891329,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 25.24631956, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.32239739, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177])),
#  ('Pratik Mutha',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/bioe/fac-pratik',
#   'https://scholar.google.co.in/citations?user=PejUtIQAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/bioe/fac-pratik/78470844-1679554160/prateek.JPG',
#   array([22.11037414, 21.05727177, 21.05727177, 21.05727177, 21.92891329,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.74631956, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 20.82239739, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177])),
#  ('Krishna Prasad Miyapuram',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/krishna',
#   'https://scholar.google.co.in/citations?user=R20YmxkAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/krishna/3621938376-1679554159/1-krishna.jpg',
#   array([18.61037414, 17.55727177, 17.55727177, 17.55727177, 18.42891329,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 18.24631956, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.32239739, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177])),
#  ('Mayank Singh',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/mayank',
#   'https://scholar.google.co.in/citations?user=U2NUj90AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/mayank/923634747-1679554159/mayank.jpg',
#   array([18.11037414, 17.05727177, 17.05727177, 17.05727177, 17.92891329,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.74631956, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 16.82239739, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177])),
#  ('Udit Bhatia',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/civil/fac-udit',
#   'https://scholar.google.co.in/citations?user=tYqY-VoAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/civil/fac-udit/2308710421-1679554160/0udit.jpg',
#   array([17.61037414, 16.55727177, 16.55727177, 16.55727177, 17.42891329,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 17.24631956, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.32239739, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177]))]

# %%
import concurrent.futures
import requests
from bs4 import BeautifulSoup

def get_scholar_data(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299'
    }
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    publications = []

    def extract_publication(pub):
        try:
            title = pub.select('.gsc_a_at')[0].text.strip()
            venue = pub.select('.gsc_a_jc')[0].text.strip()
            year = int(pub.select('.gsc_a_y')[0].text.strip())
            if year >= (pd.datetime.now().year - 5):
                return (title, venue, year)
        except:
            pass

    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(extract_publication, pub) for pub in soup.select('#gsc_a_b .gsc_a_tr')]

        for future in concurrent.futures.as_completed(futures):
            result = future.result()
            if result is not None:
                publications.append(result)

    return publications

def search(query):

    query = preprocess(query)
    query_synonyms = find_synonyms(query)
    query_vec = vectorizer.transform([query] + query_synonyms)
    
    cluster = km.predict(query_vec)[0]
    
    
    df_cluster = df[km.labels_ == cluster]
    
    relevance = reg.predict(query_vec)[:]
    
    ranked=[]

    exact_match = False
    for idx, row in df_cluster.iterrows():
        professor_name = row['Faculty Name'].lower()
        if query in professor_name:
            exact_match = True
            ranked = [(row['Faculty Name'], row['Institution'],row['HomePage'], row['Scholar Url'], row['Image'])]
            break
    
    if exact_match:
      return ranked

    def process_row(row):
        if row['h_index'] == float('nan') or pd.isna(row['h_index']):
            return None
        
        research_interests = row['Reasearch Interests']
        research_interests_words = [word for interest in research_interests for word in interest.split()]
        query_words = query.split() + query_synonyms
        if not any(word in research_interests_words for word in query_words):
            return None

        h_index = row['h_index']
        i10_index = row['i10_index'] if not pd.isna(row['i10_index']) else 0
        scholar_url = row['Scholar Url']
        if pd.isna(scholar_url):
            return None

        try:
            publications = get_scholar_data(scholar_url)
        except:
            publications = []

        recent_activity = sum([int(pub[2] >= (pd.datetime.now().year - 5)) for pub in publications])
        rank = 0.5 * (h_index + i10_index) + 0.3 * relevance + 0.2 * recent_activity # weights based on importance
        return (row['Faculty Name'], row['Institution'], row['HomePage'], row['Scholar Url'], row['Image'], rank)

    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(process_row, row) for idx, row in df_cluster.iterrows()]
        results = [future.result() for future in concurrent.futures.as_completed(futures) if future.result() is not None]

    results.sort(key=lambda x: max(x[5]), reverse=True)
    return results

# %%
search('deep learning')
# Out:
# [('Anirban Dasgupta',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/anirban',
#   'https://scholar.google.co.in/citations?user=plJC8R0AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/anirban/729890348-1679554159/anirban.jpg',
#   array([48.11037414, 47.05727177, 47.05727177, 47.05727177, 47.92891329,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.74631956, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 46.82239739, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177, 47.05727177, 47.05727177, 47.05727177,
#          47.05727177, 47.05727177])),
#  ('Ravi Hegde',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/ee/fac-ravi',
#   'https://scholar.google.co.in/citations?user=aHWM-b8AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/ee/fac-ravi/2150411337-1679554160/ravi.JPG',
#   array([28.61037414, 27.55727177, 27.55727177, 27.55727177, 28.42891329,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 28.24631956, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.32239739, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177, 27.55727177, 27.55727177, 27.55727177,
#          27.55727177, 27.55727177])),
#  ('Nipun Batra',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/nipun',
#   'https://scholar.google.co.in/citations?user=rFGzHlIAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/nipun/3587009419-1679554159/nipun.jpg',
#   array([25.61037414, 24.55727177, 24.55727177, 24.55727177, 25.42891329,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 25.24631956, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.32239739, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177, 24.55727177, 24.55727177, 24.55727177,
#          24.55727177, 24.55727177])),
#  ('Pratik Mutha',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/bioe/fac-pratik',
#   'https://scholar.google.co.in/citations?user=PejUtIQAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/bioe/fac-pratik/78470844-1679554160/prateek.JPG',
#   array([22.11037414, 21.05727177, 21.05727177, 21.05727177, 21.92891329,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.74631956, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 20.82239739, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177, 21.05727177, 21.05727177, 21.05727177,
#          21.05727177, 21.05727177])),
#  ('Krishna Prasad Miyapuram',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/krishna',
#   'https://scholar.google.co.in/citations?user=R20YmxkAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/krishna/3621938376-1679554159/1-krishna.jpg',
#   array([18.61037414, 17.55727177, 17.55727177, 17.55727177, 18.42891329,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 18.24631956, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.32239739, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177, 17.55727177, 17.55727177, 17.55727177,
#          17.55727177, 17.55727177])),
#  ('Mayank Singh',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/mayank',
#   'https://scholar.google.co.in/citations?user=U2NUj90AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/mayank/923634747-1679554159/mayank.jpg',
#   array([18.11037414, 17.05727177, 17.05727177, 17.05727177, 17.92891329,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.74631956, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 16.82239739, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177, 17.05727177, 17.05727177, 17.05727177,
#          17.05727177, 17.05727177])),
#  ('Udit Bhatia',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/civil/fac-udit',
#   'https://scholar.google.co.in/citations?user=tYqY-VoAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/civil/fac-udit/2308710421-1679554160/0udit.jpg',
#   array([17.61037414, 16.55727177, 16.55727177, 16.55727177, 17.42891329,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 17.24631956, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.32239739, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177, 16.55727177, 16.55727177, 16.55727177,
#          16.55727177, 16.55727177]))]

# %% [markdown]
# #Cleaning and Getting data to desired format

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/IIT Goa_faculty.csv')

# %%
for i in range(len(df['Department'])):
  df['Department'][i]=df['Department'].str.split('\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t')[i][1]

# %%
df=df.sort_values('Department')

# %%
df.rename(columns = {'Department':'Field', 'Home Page':'HomePage',
                              'Thumbnail':'Image','Research interests':'Research Interests'}, inplace = True)

# %%
df=df.drop('Designation',axis=1)

# %%
df=df.iloc[:,[1,2,4,3,0]]

# %%
for i in range(len(df)):
  df['Research Interests'][i]=df['Research Interests'][i].split(',')

# %%
df
# Out:
#                        Faculty Name  \
# 17                Dr. Kedar   Joshi
# 19                Dr. Mantu  Santra
# 25                 Dr. Raja   Mitra
# 13    Dr. E. Siva  Subramaniam Iyer
# 28           Dr. Rishikesh  Narayan
# 47            Dr. Sudakshina  Dutta
# 8                Dr. Arpita  Korwar
# 24                   Dr. Rahul  C S
# 22              Dr. Neha  Karanjkar
# 12           Dr. Divya  Padmanabhan
# 36             Dr. Satyanath   Bhat
# 43              Dr. Shitala  Prasad
# 4               Dr. Amaldev  Manuel
# 41               Dr. Sharad   Sinha
# 11      Dr. Clint Pazhayidam George
# 45                Dr. Sreejith  A V
# 52                  Dr. Sunil  Paul
# 42             Dr. Sheron  Figarado
# 1        Prof. Bidyadhar    Subudhi
# 21       Dr. Neelakandan  Rajamohan
# 51                   Dr. Sunil Dutt
# 35       Dr. Sashidhar  Sampathirao
# 50            Dr. Sujit Kumar Sahoo
# 6              Dr. Apeksha Madhukar
# 20          Dr. Nandakumar  Nambath
# 40           Dr. Shakthi   Prasad D
# 10            Dr. Bidhan  Pramanick
# 30              Dr. Sabiha  Hashami
# 37       Dr. Satyaprakash   Ahirwar
# 0               Prof. B. K.  Mishra
# 44                 Dr. Shiv  Parsad
# 18            Dr. Lok Pati Tripathi
# 32                 Dr. Sandipan  De
# 16     Dr. Kalpesh Jayantilal Haria
# 39             Dr. Saurabh  Trivedi
# 3          Dr. Abhitosh    Upadhyay
# 26                Dr. Rajeev  Gupta
# 38              Dr. Saumya   Bajpai
# 48           Dr. Sudhakar   Yogaraj
# 27  Dr. Rajesh    S. Prabhu Gaonkar
# 31              Dr. Sandip   Haldar
# 29            Dr. Rudra Narayan Roy
# 53          Dr. Thaseem   Thajudeen
# 23            Dr. Ponnulakshmi  V K
# 14             Dr. Harpreet   Singh
# 9               Dr. Ashish  Bhateja
# 7                  Dr. Arindam  Das
# 5             Dr. Anirudha  Ambekar
# 2        Prof. Sachin Dnyandeo Kore
# 46      Dr. Sreenath   Balakrishnan
# 33              Dr. Santosh   Kumar
# 15            Dr. Jhuma  Sannigrahi
# 49             Dr. Sudipta  Kanungo
# 34            Dr. Santosh Kumar Das
# 19  [Theoretical and computational Biophysical Che...
# 25  [Organometallic Chemistry,  Mechanically Inter...
# 13  [Physical Chemistry,  Time resolved Spectrosco...
# 28  [Synthetic Organic Chemistry,  Enantioselectiv...
# 47            [Formal Verification,  Static analysis]
# 8   [Area of research: Theoretical Computer Scienc...
# 24  [Graph Theory,  Algorithm Analysis,  & Combina...
# 22  [Modeling,  Simulation and Optimization of Dis...
# 12  [Distributionally Robust Optimization,  Extrem...
# 36  [Game theory,  Mechanism Design,  Incentive Co...
# 43  [Deep Learning,  Computer Vision,  Pattern Rec...
# 4   [Logic in Computer ScienceAutomata TheoryFinit...
# 41  [Computer Architecture (Processors,  FPGAs,  O...
# 11               [Machine learningApplied statistics]
# 45  [Logic,  Automata Theory,  Formal Methods,  an...
# 52  [Macroeconomics,  monetary economics and appli...
# 42  [Induction Motor drives,  Multilevel Inverters...
# 1   [System & Control Theory,  Robust and Adaptive...
# 21  [Wireless communication,  5G and Beyond networ...
# 51  [CMOS Digital VLSI Circuit/System Design,  Com...
# 35  [Design and finite-element modelling of electr...
# 50  [Signal Processing,  Sparse Representation,  C...
# 6   [Industrial Application of high voltage,  Non ...
# 20  [Integrated Circuits and Systems,  Optimizatio...
# 40  [High voltage engineering,  Insulation enginee...
# 10  [MEMS and Microsystems,  Carbon-MEMS,  Microfa...
# 30  [Sociolinguistics,  Contact linguistics,  Lang...
# 37  [Functionalized Nanostructured Materials: Synt...
# 0   [Extractive Metallurgy,  Thermal Plasma,  Part...
# 44  [Hyperbolic geometry,  mapping class groups of...
# 18       [Numerical Analysis,  Computational Finance]
# 32  [Quantum algebras,  Operator algebras and Oper...
# 16                                  [Operator Theory]
# 39  [Singularity Theory,  Lipschitz Geometry of Si...
# 3          [Differential Geometry,  Complex Geometry]
# 26  [Operator Theory,  Grothendieck Inequality,  D...
# 38  [Numerical Analysis,  Partial differential equ...
# 48  [Computational mechanics,  Fluid-structure int...
# 27  [Reliability Engineering,  Maintenance Enginee...
# 31     [Composite Materials,  Experimental Mechanics]
# 29  [Turbulent reacting flows,  modelling of turbu...
# 53  [Characterization of aerosol and colloidal nan...
# 23  [Radiative heat transfer,  High Reynolds numbe...
# 14  [Computational Mechanics,  Impact Mechanics,  ...
# 9   [Mechanics of granular media and particulate m...
# 7   [Interfacial Science: Wettability,  Adhesion, ...
# 5   [Experimental combustion diagnostics and chara...
# 2   [Electromagnetic Manufacturing ,  Electromagne...
# 46  [Mechanical modelling of biological cells,  Bi...
# 33  [Solid-state Quantum Photonics,  Fundamentals ...
# 15  [Experimental Condensed Matter Physics with sp...
# 49  [Density Functional Theory based electronic st...
# 34  [Heavy-ion collisions,  Quark gluon plasma,  Q...
# 54  [Theoretical Physics: Biological Physics,  Sta...
#
#                                                 Image
# 17   http://iitgoa.ac.in/wp-content/uploads/kedar.jpg
# 19   http://iitgoa.ac.in/wp-content/uploads/mantu.jpg
# 25  http://iitgoa.ac.in/wp-content/uploads/rajamit...
# 13  http://iitgoa.ac.in/wp-content/uploads/essiyer...
# 18  http://iitgoa.ac.in/wp-content/uploads/lokpati...
# 32  http://iitgoa.ac.in/wp-content/uploads/sandipa...
# 16  http://iitgoa.ac.in/wp-content/uploads/kalpesh...
# 39  http://iitgoa.ac.in/wp-content/uploads/saurabh...
# 3   http://iitgoa.ac.in/wp-content/uploads/abhitos...
# 26  http://iitgoa.ac.in/wp-content/uploads/rajeev.jpg
# 38  http://iitgoa.ac.in/wp-content/uploads/saumya.jpg
# 48  http://iitgoa.ac.in/wp-content/uploads/sudhaka...
# 27     http://iitgoa.ac.in/wp-content/uploads/rpg.jpg
# 31  http://iitgoa.ac.in/wp-content/uploads/sandip.jpg
# 29   http://iitgoa.ac.in/wp-content/uploads/rudra.jpg
# 53  http://iitgoa.ac.in/wp-content/uploads/thaseem...
# 23   http://iitgoa.ac.in/wp-content/uploads/ponnu.jpg
# 14  http://iitgoa.ac.in/wp-content/uploads/harpree...
# 9   http://iitgoa.ac.in/wp-content/uploads/ashish.jpg
# 7   http://iitgoa.ac.in/wp-content/uploads/arindam...
# 5   http://iitgoa.ac.in/wp-content/uploads/anirudh...
# 2   http://iitgoa.ac.in/wp-content/uploads/sachin.jpg
# 46  http://iitgoa.ac.in/wp-content/uploads/sreenat...
# 33  http://iitgoa.ac.in/wp-content/uploads/skumar.jpg
# 15   http://iitgoa.ac.in/wp-content/uploads/jhuma.jpg
# 49  http://iitgoa.ac.in/wp-content/uploads/sudipta...
# 34  http://iitgoa.ac.in/wp-content/uploads/santosh...
# 54  http://iitgoa.ac.in/wp-content/uploads/wasnik.jpg

# %%
df.to_csv('/content/IITGoa_Faculty.csv',index=False)

# %% [markdown]
# #Getting Google Scholar Profile from Faculty Name

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/IITGoa_Faculty.csv')

# %%
# !pip install scholarly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scholarly in /usr/local/lib/python3.9/dist-packages (1.7.11)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/dist-packages (from scholarly) (0.24.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.2.13)
# Requirement already satisfied: arrow in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.2.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.11.2)
# Requirement already satisfied: free-proxy in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.1.1)
# Requirement already satisfied: bibtexparser in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.4.0)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.2.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.1.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from scholarly) (2.27.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.5.0)
# Requirement already satisfied: selenium in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.9.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.9/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->scholarly) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.9/dist-packages (from bibtexparser->scholarly) (3.0.9)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->scholarly) (1.14.1)
# Requirement already satisfied: importlib-resources>=5.0 in /usr/local/lib/python3.9/dist-packages (from fake-useragent->scholarly) (5.12.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from free-proxy->scholarly) (4.9.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (2022.12.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (0.17.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (1.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.26.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.9/dist-packages (from selenium->scholarly) (0.10.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.9/dist-packages (from selenium->scholarly) (0.22.0)
# Requirement already satisfied: sphinxcontrib-jquery!=3.0.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (4.1)
# Requirement already satisfied: sphinx<7,>=1.6 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (3.5.4)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (0.16)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (3.6.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (0.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=5.0->fake-useragent->scholarly) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.16.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.12.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (67.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (23.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.14.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (3.1.2)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (0.7.13)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.1.5)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.4)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (23.1.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.9/dist-packages (from trio-websocket~=0.9->selenium->scholarly) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.3->sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.1.2)

# %%
from scholarly import scholarly

# %%
def get_google_scholar_url(name,institution):
    search_query = scholarly.search_author(f'{name} {institution}')
    author = next(search_query, None)

    if author is None:
        return None
    return "https://scholar.google.co.in/citations?user="+author['scholar_id']

faculty_name = 'Balagopal Komarath'
gs_profile_url = get_google_scholar_url(faculty_name,'IIT Gandhinagar')
print(gs_profile_url)
# Out:
# https://scholar.google.co.in/citations?user=uTv7Dl4AAAAJ

# %%
df.insert(5, 'Scholar Url', None)

# %%
faculty_names=df['Faculty Name']
institution= 'IIT Goa'
for i in range(len(df)):
  answer=get_google_scholar_url(" ".join(faculty_names[i].split()[1]),institution)
  if answer==None:
    institution='Indian Institute of Technology, Goa'
    answer=get_google_scholar_url(" ".join(faculty_names[i].split()[1]),institution)
  df['Scholar Url'][i]=answer

# %%
institution= 'IIT Goa'
for i in range(len(df)):
  if df['Scholar Url'][i]==None:
    answer=get_google_scholar_url(faculty_names[i].split()[1],institution)
    if answer==None:
      institution='Indian Institute of Technology, Goa'
      answer=get_google_scholar_url(faculty_names[i].split()[1],institution)
    df['Scholar Url'][i]=answer

# %%
import numpy as np
df=df.replace(to_replace='None', value=np.nan).dropna()

# %%
df.to_csv('/content/IITGoa_Faculty.csv',index=False)

# %%
df.insert(6, 'h_index', None)
df.insert(7, 'i10_index', None)

# %%
df=df.reset_index()

# %%
from bs4 import BeautifulSoup
import urllib.request
def get_h_and_i(url):
  page = urllib.request.urlopen(url)
  soup = BeautifulSoup(page, 'html.parser') 
  indexes = soup.find_all("td", "gsc_rsb_std")
  if len(indexes)>0:
    h_index = indexes[2].string
    i10_index = indexes[4].string
    return h_index,i10_index
  return 0,0
for i in range(len(df)):
  if(type(df['Scholar Url'][i])!=float):
    df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
# Out:
# <ipython-input-90-0bdf00360499>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))

# %%
for i in range(len(df)):
  df['h_index'][i]=int(df['h_index'][i][0])
  df['i10_index'][i]=int(df['i10_index'][i][0])
# Out:
# <ipython-input-103-f9015568e20c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i]=int(df['h_index'][i][0])
# <ipython-input-103-f9015568e20c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['i10_index'][i]=int(df['i10_index'][i][0])

# %%
df.to_csv('/content/IITGoa_Faculty.csv',index=False)

# %% [markdown]
# #Combining dataset

# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/IITGN_FACULTY.csv')
df2=pd.read_csv('/content/IITGoa_Faculty.csv')

# %%
df=pd.concat([df1.iloc[:,[1,2,3,4,5,6,7,8,9]],df2.iloc[:,[1,2,3,4,5,6,7,8,9]]])

# %%
df.to_csv('Combined_Faculty.csv',index=False)

# %% [markdown]
# # IIT GOA Data cleaning

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/IITGUWA_200.csv')

# %%
df.sort_values('name_Field')
# Out:
#                                name_name  \
# 60                          Debasish Das
# 109                      Nitin Chaudhary
# 125                       Pranab Goswami
# 45                 Bithiah G. Jaganathan
# 135                  Rajaram Swaminathan
# ..                                   ...
# 128                    Pravat Kumar Giri
# 55                                D Pamu
# 71                 Girish Sampath Setlur
# 161  Sashindra K. Kakoty (Founder, SART)
# 199                       Tamal Banerjee
#
#                                               name_url  \
# 60   https://iitg.ac.in/iitg_faculty_details?name=D...
# 109  https://iitg.ac.in/iitg_faculty_details?name=N...
# 125  https://iitg.ac.in/iitg_faculty_details?name=P...
# 45   https://iitg.ac.in/iitg_faculty_details?name=B...
# 135  https://iitg.ac.in/iitg_faculty_details?name=R...
# ..                                                 ...
# 128  https://iitg.ac.in/iitg_faculty_details?name=P...
# 55   https://iitg.ac.in/iitg_faculty_details?name=D...
# 71   https://iitg.ac.in/iitg_faculty_details?name=G...
# 161  https://iitg.ac.in/iitg_faculty_details?name=S...
# 199  https://iitg.ac.in/iitg_faculty_details?name=T...
#
#                                             name_image  \
# 60      https://iitg.ac.in/storage/faculty/7016img.jpg
# 109     https://iitg.ac.in/storage/faculty/5233img.jpg
# 125     https://iitg.ac.in/storage/faculty/5584img.jpg
# 45      https://iitg.ac.in/storage/faculty/3028img.jpg
# 135     https://iitg.ac.in/storage/faculty/2185img.jpg
# ..                                                 ...
# 128  https://iitg.ac.in/storage/faculty/891faculty.JPG
# 55   https://iitg.ac.in/storage/faculty/4558faculty...
# 71   https://iitg.ac.in/storage/faculty/2156faculty...
# 161       https://iitg.ac.in/storage/faculty/960sk.jpg
# 199  https://iitg.ac.in/storage/faculty/9354faculty...
#
#                                         name_image_url  \
# 60   https://iitg.ac.in/iitg_faculty_details?name=D...
# 109  https://iitg.ac.in/iitg_faculty_details?name=N...
# 125  https://iitg.ac.in/iitg_faculty_details?name=P...
# 45   https://iitg.ac.in/iitg_faculty_details?name=B...
# 135  https://iitg.ac.in/iitg_faculty_details?name=R...
# ..                                                 ...
# 128  https://iitg.ac.in/iitg_faculty_details?name=P...
# 55   https://iitg.ac.in/iitg_faculty_details?name=D...
# 71   https://iitg.ac.in/iitg_faculty_details?name=G...
# 161  https://iitg.ac.in/iitg_faculty_details?name=S...
# 199  https://iitg.ac.in/iitg_faculty_details?name=T...
#
#                                name_Research_interests  \
# 60   Metabolic engineering, Biochemical engineering...
# 109  Peptide self-assembly and amyloid aggregates, ...
# 125                       Biosensors and Biofuel cells
# 45                 Stem Cell Biology, Cancer signaling
# 135  A. Biophotonics B. Protein Structure and Dynam...
# ..                                                 ...
# 128  Semiconductor nanostructures, Ion-solid intera...
# 55   High-k and low loss materials, FerroelectricsC...
# 71   Theoretical Physics; Nonchiral Bosonization in...
# 161  Rural Technology | Mechanical System Design | ...
# 199                                                NaN
#
#                                             name_Field
# 60                      Biosciences and Bioengineering
# 109                     Biosciences and Bioengineering
# 125                     Biosciences and Bioengineering
# 45                      Biosciences and Bioengineering
# 135                     Biosciences and Bioengineering
# ..                                                 ...
# 128                  Physics Centre for Nanotechnology
# 55                   Physics Centre for Nanotechnology
# 71   Physics Mehta Family School of Data Science an...
# 161  School of Business Mechanical Engineering Scho...
# 199                                                NaN
#
# [200 rows x 6 columns]

# %%
df.rename(columns = {'name_Field':'Field', 'name_url':'HomePage',
                              'name_image':'Image','name_Research_interests':'Research Interests',
                              'name_name':'Faculty Name'}, inplace = True)

# %%
df=df.drop('name_image_url',axis=1)

# %%
df=df.iloc[:,[0,4,1,3,2]]

# %%
df.insert(0,'Institution','Indian Institute of Technology Guwahati')

# %%
# !pip install scholarly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scholarly
#   Downloading scholarly-1.7.11-py3-none-any.whl (39 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.11.2)
# Collecting bibtexparser
#   Downloading bibtexparser-1.4.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fake-useragent
#   Downloading fake_useragent-1.1.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.9 MB/s eta 0:00:00
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from scholarly) (2.27.1)
# Collecting arrow
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.2 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting selenium
#   Downloading selenium-4.9.0-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 65.9 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 5.3 MB/s eta 0:00:00
# Collecting free-proxy
#   Downloading free_proxy-1.1.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.9/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->scholarly) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.9/dist-packages (from bibtexparser->scholarly) (3.0.9)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->scholarly) (1.14.1)
# Requirement already satisfied: importlib-resources>=5.0 in /usr/local/lib/python3.9/dist-packages (from fake-useragent->scholarly) (5.12.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from free-proxy->scholarly) (4.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (1.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (2022.12.7)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 27.4 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (0.16)
# Requirement already satisfied: sphinx<7,>=1.6 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (3.5.4)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (3.6.2)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=5.0->fake-useragent->scholarly) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.16.0)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.14.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.1.5)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.12.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (67.6.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (3.1.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (0.7.13)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.3)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.0.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (23.1)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (23.1.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.1.1)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.3->sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.1.2)
# Building wheels for collected packages: bibtexparser, free-proxy
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.0-py3-none-any.whl size=42444 sha256=349a095bb45f32db3419e0c66662097a88dfbd9165b3d9f2cb2bd32cd0ddeb28
#   Stored in directory: /root/.cache/pip/wheels/83/e1/e3/2311be27728119eefd014e0a6039eee58470560d8ab31fd1fa
#   Building wheel for free-proxy (setup.py) ... done
#   Created wheel for free-proxy: filename=free_proxy-1.1.1-py3-none-any.whl size=5652 sha256=369923c3cf9e33e5bb5e5b0ccfb0eaaeda908f78a514a87a16679bd8ba576cce
#   Stored in directory: /root/.cache/pip/wheels/a9/38/db/3efef5f071876e3a6888f9933d636c6b764655a96a32d78f4e
# Successfully built bibtexparser free-proxy
# Installing collected packages: python-dotenv, outcome, h11, deprecated, bibtexparser, async-generator, wsproto, trio, httpcore, free-proxy, fake-useragent, arrow, trio-websocket, sphinxcontrib-jquery, httpx, sphinx-rtd-theme, selenium, scholarly
# Successfully installed arrow-1.2.3 async-generator-1.10 bibtexparser-1.4.0 deprecated-1.2.13 fake-useragent-1.1.3 free-proxy-1.1.1 h11-0.14.0 httpcore-0.17.0 httpx-0.24.0 outcome-1.2.0 python-dotenv-1.0.0 scholarly-1.7.11 selenium-4.9.0 sphinx-rtd-theme-1.2.0 sphinxcontrib-jquery-4.1 trio-0.22.0 trio-websocket-0.10.2 wsproto-1.2.0

# %%
from scholarly import scholarly

# %%
def get_google_scholar_url(name,institution):
    search_query = scholarly.search_author(f'{name} {institution}')
    author = next(search_query, None)

    if author is None:
        return None
    return "https://scholar.google.co.in/citations?user="+author['scholar_id']

# %%
df.insert(5, 'Scholar Url', None)

# %%
faculty_names=df['Faculty Name']
institution= 'IIT Guwahati'
for i in range(len(df)):
  answer=get_google_scholar_url(" ".join(faculty_names[i].split()[1]),institution)
  if answer==None:
    institution='Indian Institute of Technology Guwahati'
    answer=get_google_scholar_url(" ".join(faculty_names[i].split()[1]),institution)
  df['Scholar Url'][i]=answer
# Out:
# <ipython-input-38-7885f8c44087>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Scholar Url'][i]=answer

# %%
df.to_csv('/content/IITG_Faculty.csv',index=False)

# %%
df=pd.read_csv('/content/IITG_Faculty.csv')

# %%
import numpy as np
df=df.replace(to_replace='None', value=np.nan).dropna()

# %%
df.insert(6, 'h_index', None)
df.insert(7, 'i10_index', None)
df=df.reset_index()

# %%
from bs4 import BeautifulSoup
import urllib.request
def get_h_and_i(url):
  page = urllib.request.urlopen(url)
  soup = BeautifulSoup(page, 'html.parser') 
  indexes = soup.find_all("td", "gsc_rsb_std")
  if len(indexes)>0:
    h_index = indexes[2].string
    i10_index = indexes[4].string
    return h_index,i10_index
  return 0,0
for i in range(len(df)):
  if(type(df['Scholar Url'][i])!=float):
    df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
for i in range(len(df)):
  df['h_index'][i]=int(df['h_index'][i][0])
  df['i10_index'][i]=int(df['i10_index'][i][0])
# Out:
# <ipython-input-45-ed6949983c23>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
# <ipython-input-45-ed6949983c23>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i]=int(df['h_index'][i][0])
# <ipython-input-45-ed6949983c23>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['i10_index'][i]=int(df['i10_index'][i][0])

# %%
df.to_csv('/content/IITG_Faculty.csv',index=False)

# %% [markdown]
# # IITGN FACULTY DATA

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/true_final_faculty_iitgn.csv')

# %%
df=df.drop('Unnamed: 0.2',axis=1)

# %%
df=df.drop('Scholar Url',axis=1)

# %%
df=df.drop(['h_index','i10_index','text'],axis=1)

# %%
df.rename({'Reasearch Interests':'Research Interests'})
# Out:
#                                     Institution              Faculty Name  \
# 0    Indian Institute of Technology Gandhinagar       Ashutosh Srivastava
# 1    Indian Institute of Technology Gandhinagar             Bhaskar Datta
# 2    Indian Institute of Technology Gandhinagar             Dhiraj Bhatia
# 3    Indian Institute of Technology Gandhinagar  Karla P. Mercado-Shekhar
# 4    Indian Institute of Technology Gandhinagar             Mukesh Dhanka
# ..                                          ...                       ...
# 97   Indian Institute of Technology Gandhinagar             Uttama Lahiri
# 98   Indian Institute of Technology Gandhinagar              Aashish Xaxa
# 99   Indian Institute of Technology Gandhinagar        Alok Kumar Kanungo
# 100  Indian Institute of Technology Gandhinagar          Ambika Aiyadurai
# 101  Indian Institute of Technology Gandhinagar             Angus McBlane
#
#                             Field  \
# 0          Biological Engineering
# 1          Biological Engineering
# 2          Biological Engineering
# 3          Biological Engineering
# 4          Biological Engineering
# ..                            ...
# 97         Electrical Engineering
# 98   Humanities & Social Sciences
# 99   Humanities & Social Sciences
# 100  Humanities & Social Sciences
# 101  Humanities & Social Sciences
#
#                                           HomePage  \
# 0    https://iitgn.ac.in/faculty/bioe/fac-ashutosh
# 1     https://iitgn.ac.in/faculty/bioe/fac-bhaskar
# 2      https://iitgn.ac.in/faculty/bioe/fac-dhiraj
# 3       https://iitgn.ac.in/faculty/bioe/fac-karla
# 4      https://iitgn.ac.in/faculty/bioe/fac-mukesh
# ..                                             ...
# 97       https://iitgn.ac.in/faculty/ee/fac-uttama
# 98     https://iitgn.ac.in/faculty/hss/fac-aashish
# 99        https://iitgn.ac.in/faculty/hss/fac-alok
# 100     https://iitgn.ac.in/faculty/hss/fac-ambika
# 101      https://iitgn.ac.in/faculty/hss/fac-angus
#
#                                    Reasearch Interests
# 0    ['Integrative modeling of macromolecular compl...
# 1    ['Investigation of groove-modified nucleobases...
# 2           ['DNA nanotechnology', 'Chemical biology']
# 3    ['Tissue elasticity imaging', 'Shear wave imag...
# 4    ['Allograft Therapy', 'Biomaterials', 'Drug De...
# ..                                                 ...
# 97   ['Virtual Reality based Human Computer Interac...
# 98   ['Development Studies', 'Urban Development', '...
# 99   ['Who owns the past', 'Understanding history a...
# 100  ['Biodiversity conservation', 'Human-animal re...
# 101  ['Cultural theory', 'Embodiment', 'Environment...
#
# [102 rows x 5 columns]

# %%
# !pip install scholarly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scholarly
#   Downloading scholarly-1.7.11-py3-none-any.whl (39 kB)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 21.3 MB/s eta 0:00:00
# Collecting fake-useragent
#   Downloading fake_useragent-1.1.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.1 MB/s eta 0:00:00
# Collecting bibtexparser
#   Downloading bibtexparser-1.4.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting free-proxy
#   Downloading free_proxy-1.1.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.11.2)
# Collecting selenium
#   Downloading selenium-4.9.0-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 76.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.5.0)
# Collecting arrow
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.6 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from scholarly) (2.27.1)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.9/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->scholarly) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.9/dist-packages (from bibtexparser->scholarly) (3.0.9)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->scholarly) (1.14.1)
# Requirement already satisfied: importlib-resources>=5.0 in /usr/local/lib/python3.9/dist-packages (from fake-useragent->scholarly) (5.12.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from free-proxy->scholarly) (4.9.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (2022.12.7)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (1.3.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 32.5 MB/s eta 0:00:00
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (0.16)
# Requirement already satisfied: sphinx<7,>=1.6 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (3.5.4)
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 13.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (3.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=5.0->fake-useragent->scholarly) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.16.0)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.14.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.12.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (3.1.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (0.7.13)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.0.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.1.5)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (23.1)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (67.6.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.3)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (23.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.1.1)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.3->sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.1.2)
# Building wheels for collected packages: bibtexparser, free-proxy
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.0-py3-none-any.whl size=42444 sha256=724d27dda542499164902da25c8522cef8b8f9480b18b29838c26532ef0ef113
#   Stored in directory: /root/.cache/pip/wheels/83/e1/e3/2311be27728119eefd014e0a6039eee58470560d8ab31fd1fa
#   Building wheel for free-proxy (setup.py) ... done
#   Created wheel for free-proxy: filename=free_proxy-1.1.1-py3-none-any.whl size=5652 sha256=faa69c6889759a3beda6de1022071652f36e10dad2cb13b94d9c0e8cce5887c2
#   Stored in directory: /root/.cache/pip/wheels/a9/38/db/3efef5f071876e3a6888f9933d636c6b764655a96a32d78f4e
# Successfully built bibtexparser free-proxy
# Installing collected packages: python-dotenv, outcome, h11, deprecated, bibtexparser, async-generator, wsproto, trio, httpcore, free-proxy, fake-useragent, arrow, trio-websocket, sphinxcontrib-jquery, httpx, sphinx-rtd-theme, selenium, scholarly
# Successfully installed arrow-1.2.3 async-generator-1.10 bibtexparser-1.4.0 deprecated-1.2.13 fake-useragent-1.1.3 free-proxy-1.1.1 h11-0.14.0 httpcore-0.17.0 httpx-0.24.0 outcome-1.2.0 python-dotenv-1.0.0 scholarly-1.7.11 selenium-4.9.0 sphinx-rtd-theme-1.2.0 sphinxcontrib-jquery-4.1 trio-0.22.0 trio-websocket-0.10.2 wsproto-1.2.0

# %%
from scholarly import scholarly

# %%
def get_google_scholar_url(name,institution):
    search_query = scholarly.search_author(f'{name} {institution}')
    author = next(search_query, None)

    if author is None:
        return None
    return "https://scholar.google.co.in/citations?user="+author['scholar_id']

# %%
df.insert(5, 'Scholar Url', None)

# %%
faculty_names=df['Faculty Name']
institution= 'IIT Gandhinagar'
for i in range(len(df)):
  answer=get_google_scholar_url(" ".join(faculty_names[i].split()[0]),institution)
  if answer==None:
    institution='Indian Institute of Technology Gandhinagar'
    answer=get_google_scholar_url(" ".join(faculty_names[i].split()[0]),institution)
  df['Scholar Url'][i]=answer

# %%
df1=df

# %%
df1
# Out:
#                                     Institution              Faculty Name  \
# 0    Indian Institute of Technology Gandhinagar       Ashutosh Srivastava
# 1    Indian Institute of Technology Gandhinagar             Bhaskar Datta
# 2    Indian Institute of Technology Gandhinagar             Dhiraj Bhatia
# 3    Indian Institute of Technology Gandhinagar  Karla P. Mercado-Shekhar
# 4    Indian Institute of Technology Gandhinagar             Mukesh Dhanka
# ..                                          ...                       ...
# 97   Indian Institute of Technology Gandhinagar             Uttama Lahiri
# 98   Indian Institute of Technology Gandhinagar              Aashish Xaxa
# 99   Indian Institute of Technology Gandhinagar        Alok Kumar Kanungo
# 100  Indian Institute of Technology Gandhinagar          Ambika Aiyadurai
# 101  Indian Institute of Technology Gandhinagar             Angus McBlane
#
#                             Field  \
# 0          Biological Engineering
# 1          Biological Engineering
# 2          Biological Engineering
# 3          Biological Engineering
# 4          Biological Engineering
# ..                            ...
# 97         Electrical Engineering
# 98   Humanities & Social Sciences
# 99   Humanities & Social Sciences
# 100  Humanities & Social Sciences
# 101  Humanities & Social Sciences
#
#                                           HomePage  \
# 0    https://iitgn.ac.in/faculty/bioe/fac-ashutosh
# 1     https://iitgn.ac.in/faculty/bioe/fac-bhaskar
# 2      https://iitgn.ac.in/faculty/bioe/fac-dhiraj
# 3       https://iitgn.ac.in/faculty/bioe/fac-karla
# 4      https://iitgn.ac.in/faculty/bioe/fac-mukesh
# ..                                             ...
# 97       https://iitgn.ac.in/faculty/ee/fac-uttama
# 98     https://iitgn.ac.in/faculty/hss/fac-aashish
# 99        https://iitgn.ac.in/faculty/hss/fac-alok
# 100     https://iitgn.ac.in/faculty/hss/fac-ambika
# 101      https://iitgn.ac.in/faculty/hss/fac-angus
#
#                                    Reasearch Interests  \
# 0    ['Integrative modeling of macromolecular compl...
# 1    ['Investigation of groove-modified nucleobases...
# 2           ['DNA nanotechnology', 'Chemical biology']
# 3    ['Tissue elasticity imaging', 'Shear wave imag...
# 4    ['Allograft Therapy', 'Biomaterials', 'Drug De...
# ..                                                 ...
# 97   ['Virtual Reality based Human Computer Interac...
# 98   ['Development Studies', 'Urban Development', '...
# 99   ['Who owns the past', 'Understanding history a...
# 100  ['Biodiversity conservation', 'Human-animal re...
# 101  ['Cultural theory', 'Embodiment', 'Environment...
#
#                                            Scholar Url
# 0    https://scholar.google.co.in/citations?user=tV...
# 1    https://scholar.google.co.in/citations?user=S4...
# 2    https://scholar.google.co.in/citations?user=9_...
# 3    https://scholar.google.co.in/citations?user=UP...
# 4    https://scholar.google.co.in/citations?user=Sj...
# ..                                                 ...
# 97                                                None
# 98   https://scholar.google.co.in/citations?user=tL...
# 99                                                None
# 100  https://scholar.google.co.in/citations?user=9o...
# 101                                               None
#
# [102 rows x 6 columns]

# %%
faculty_names=df1['Faculty Name']
institution= 'IIT Gandhinagar'
for i in range(len(df)):
  if(df1['Scholar Url'][i]==None):
    answer=get_google_scholar_url(faculty_names[i],institution)
    if answer==None:
      institution='Indian Institute of Technology Gandhinagar'
      answer=get_google_scholar_url(faculty_names[i],institution)
    df1['Scholar Url'][i]=answer

# %%
import numpy as np
df1.replace(to_replace='None', value=np.nan).isna().sum()
# Out:
# Institution             0
# Faculty Name            0
# Field                   1
# HomePage                0
# Reasearch Interests     0
# Scholar Url            28
# dtype: int64

# %%
df2=pd.read_csv('/content/iitgn_faculty2.csv')

# %%
df3=df1

df1.join(df2['Image'])
# Out:
#                                     Institution              Faculty Name  \
# 0    Indian Institute of Technology Gandhinagar       Ashutosh Srivastava
# 1    Indian Institute of Technology Gandhinagar             Bhaskar Datta
# 2    Indian Institute of Technology Gandhinagar             Dhiraj Bhatia
# 3    Indian Institute of Technology Gandhinagar  Karla P. Mercado-Shekhar
# 4    Indian Institute of Technology Gandhinagar             Mukesh Dhanka
# ..                                          ...                       ...
# 97   Indian Institute of Technology Gandhinagar             Uttama Lahiri
# 98   Indian Institute of Technology Gandhinagar              Aashish Xaxa
# 99   Indian Institute of Technology Gandhinagar        Alok Kumar Kanungo
# 100  Indian Institute of Technology Gandhinagar          Ambika Aiyadurai
# 101  Indian Institute of Technology Gandhinagar             Angus McBlane
#
#                             Field  \
# 0          Biological Engineering
# 1          Biological Engineering
# 2          Biological Engineering
# 3          Biological Engineering
# 4          Biological Engineering
# ..                            ...
# 97         Electrical Engineering
# 98   Humanities & Social Sciences
# 99   Humanities & Social Sciences
# 100  Humanities & Social Sciences
# 101  Humanities & Social Sciences
#
#                                           HomePage  \
# 0    https://iitgn.ac.in/faculty/bioe/fac-ashutosh
# 1     https://iitgn.ac.in/faculty/bioe/fac-bhaskar
# 2      https://iitgn.ac.in/faculty/bioe/fac-dhiraj
# 3       https://iitgn.ac.in/faculty/bioe/fac-karla
# 4      https://iitgn.ac.in/faculty/bioe/fac-mukesh
# ..                                             ...
# 97       https://iitgn.ac.in/faculty/ee/fac-uttama
# 98     https://iitgn.ac.in/faculty/hss/fac-aashish
# 99        https://iitgn.ac.in/faculty/hss/fac-alok
# 100     https://iitgn.ac.in/faculty/hss/fac-ambika
# 101      https://iitgn.ac.in/faculty/hss/fac-angus
#
#                                    Reasearch Interests  \
# 0    ['Integrative modeling of macromolecular compl...
# 1    ['Investigation of groove-modified nucleobases...
# 2           ['DNA nanotechnology', 'Chemical biology']
# 3    ['Tissue elasticity imaging', 'Shear wave imag...
# 4    ['Allograft Therapy', 'Biomaterials', 'Drug De...
# ..                                                 ...
# 97   ['Virtual Reality based Human Computer Interac...
# 98   ['Development Studies', 'Urban Development', '...
# 99   ['Who owns the past', 'Understanding history a...
# 100  ['Biodiversity conservation', 'Human-animal re...
# 101  ['Cultural theory', 'Embodiment', 'Environment...
#
#                                            Scholar Url  \
# 0    https://scholar.google.co.in/citations?user=tV...
# 1    https://scholar.google.co.in/citations?user=S4...
# 2    https://scholar.google.co.in/citations?user=9_...
# 3    https://scholar.google.co.in/citations?user=UP...
# 4    https://scholar.google.co.in/citations?user=Sj...
# ..                                                 ...
# 97                                                None
# 98   https://scholar.google.co.in/citations?user=tL...
# 99                                                None
# 100  https://scholar.google.co.in/citations?user=9o...
# 101                                               None
#
#                                                  Image
# 0    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 1    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 2    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 3    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 4    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# ..                                                 ...
# 97   https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 98   https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 99   https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 100  https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 101                                                NaN
#
# [102 rows x 7 columns]

# %%
faculty_names=df1['Faculty Name']
for i in range(len(df)):
  if(df1['Scholar Url'][i]==None):
    institution= 'IIT Gandhinagar'
    answer=get_google_scholar_url(faculty_names[i],institution)
    print(answer)
    if answer==None:
      institution='Indian Institute of Technology Gandhinagar'
      answer=get_google_scholar_url(faculty_names[i],institution)
    df1['Scholar Url'][i]=answer
# Out:
# None
# https://scholar.google.co.in/citations?user=93c86gsAAAAJ
# None
# https://scholar.google.co.in/citations?user=EAWHyvkAAAAJ
# https://scholar.google.co.in/citations?user=qJavKW4AAAAJ
# https://scholar.google.co.in/citations?user=plJC8R0AAAAJ
# https://scholar.google.co.in/citations?user=uTv7Dl4AAAAJ
# https://scholar.google.co.in/citations?user=RcBEsucAAAAJ
# None
# https://scholar.google.co.in/citations?user=U2NUj90AAAAJ
# https://scholar.google.co.in/citations?user=rFGzHlIAAAAJ
# https://scholar.google.co.in/citations?user=QtsJ2pUAAAAJ
# None
# None
# None
# None
# None
# None
# https://scholar.google.co.in/citations?user=llQQJGMAAAAJ
# None
# None
# https://scholar.google.co.in/citations?user=kxNm_3sAAAAJ
# None
# None
# https://scholar.google.co.in/citations?user=75hNSWsAAAAJ
# https://scholar.google.co.in/citations?user=gK5-5JIAAAAJ
# None
# None

# %%
df1=df1.join(df2['Image'])

# %%
df1
# Out:
#                                     Institution              Faculty Name  \
# 0    Indian Institute of Technology Gandhinagar       Ashutosh Srivastava
# 1    Indian Institute of Technology Gandhinagar             Bhaskar Datta
# 2    Indian Institute of Technology Gandhinagar             Dhiraj Bhatia
# 3    Indian Institute of Technology Gandhinagar  Karla P. Mercado-Shekhar
# 4    Indian Institute of Technology Gandhinagar             Mukesh Dhanka
# ..                                          ...                       ...
# 97   Indian Institute of Technology Gandhinagar             Uttama Lahiri
# 98   Indian Institute of Technology Gandhinagar              Aashish Xaxa
# 99   Indian Institute of Technology Gandhinagar        Alok Kumar Kanungo
# 100  Indian Institute of Technology Gandhinagar          Ambika Aiyadurai
# 101  Indian Institute of Technology Gandhinagar             Angus McBlane
#
#                             Field  \
# 0          Biological Engineering
# 1          Biological Engineering
# 2          Biological Engineering
# 3          Biological Engineering
# 4          Biological Engineering
# ..                            ...
# 97         Electrical Engineering
# 98   Humanities & Social Sciences
# 99   Humanities & Social Sciences
# 100  Humanities & Social Sciences
# 101  Humanities & Social Sciences
#
#                                           HomePage  \
# 0    https://iitgn.ac.in/faculty/bioe/fac-ashutosh
# 1     https://iitgn.ac.in/faculty/bioe/fac-bhaskar
# 2      https://iitgn.ac.in/faculty/bioe/fac-dhiraj
# 3       https://iitgn.ac.in/faculty/bioe/fac-karla
# 4      https://iitgn.ac.in/faculty/bioe/fac-mukesh
# ..                                             ...
# 97       https://iitgn.ac.in/faculty/ee/fac-uttama
# 98     https://iitgn.ac.in/faculty/hss/fac-aashish
# 99        https://iitgn.ac.in/faculty/hss/fac-alok
# 100     https://iitgn.ac.in/faculty/hss/fac-ambika
# 101      https://iitgn.ac.in/faculty/hss/fac-angus
#
#                                    Reasearch Interests  \
# 0    ['Integrative modeling of macromolecular compl...
# 1    ['Investigation of groove-modified nucleobases...
# 2           ['DNA nanotechnology', 'Chemical biology']
# 3    ['Tissue elasticity imaging', 'Shear wave imag...
# 4    ['Allograft Therapy', 'Biomaterials', 'Drug De...
# ..                                                 ...
# 97   ['Virtual Reality based Human Computer Interac...
# 98   ['Development Studies', 'Urban Development', '...
# 99   ['Who owns the past', 'Understanding history a...
# 100  ['Biodiversity conservation', 'Human-animal re...
# 101  ['Cultural theory', 'Embodiment', 'Environment...
#
#                                            Scholar Url  \
# 0    https://scholar.google.co.in/citations?user=tV...
# 1    https://scholar.google.co.in/citations?user=S4...
# 2    https://scholar.google.co.in/citations?user=9_...
# 3    https://scholar.google.co.in/citations?user=UP...
# 4    https://scholar.google.co.in/citations?user=Sj...
# ..                                                 ...
# 97   https://scholar.google.co.in/citations?user=gK...
# 98   https://scholar.google.co.in/citations?user=tL...
# 99                                                None
# 100  https://scholar.google.co.in/citations?user=9o...
# 101                                               None
#
#                                                  Image
# 0    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 1    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 2    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 3    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# 4    https://iitgn.ac.in/media/pages/faculty/bioe/f...
# ..                                                 ...
# 97   https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 98   https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 99   https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 100  https://iitgn.ac.in/media/pages/faculty/hss/fa...
# 101                                                NaN
#
# [102 rows x 7 columns]

# %%
import numpy as np
df1=df1.replace(to_replace='None', value=np.nan).dropna()

# %%
df1.insert(6, 'h_index', None)
df1.insert(7, 'i10_index', None)
df1=df1.reset_index()

# %%
from bs4 import BeautifulSoup
import urllib.request
def get_h_and_i(url):
  page = urllib.request.urlopen(url)
  soup = BeautifulSoup(page, 'html.parser') 
  indexes = soup.find_all("td", "gsc_rsb_std")
  if len(indexes)>0:
    h_index = indexes[2].string
    i10_index = indexes[4].string
    return h_index,i10_index
  return 0,0
for i in range(len(df1)):
  if(type(df1['Scholar Url'][i])!=float):
    df1['h_index'][i],df1['i10_index'][i]=zip(get_h_and_i(df1['Scholar Url'][i]))
for i in range(len(df1)):
  df1['h_index'][i]=int(df1['h_index'][i][0])
  df1['i10_index'][i]=int(df1['i10_index'][i][0])
# Out:
# <ipython-input-89-de47a7eeb50d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['h_index'][i],df1['i10_index'][i]=zip(get_h_and_i(df1['Scholar Url'][i]))
# <ipython-input-89-de47a7eeb50d>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['h_index'][i]=int(df1['h_index'][i][0])
# <ipython-input-89-de47a7eeb50d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['i10_index'][i]=int(df1['i10_index'][i][0])

# %%
df1.to_csv('/content/IITGn_Faculty.csv',index=False)

# %% [markdown]
# #Final Changes

# %%
df1=df1.drop('Image',axis=1)

# %%
merged_df = df1.merge(df2[['Faculty Name', 'Image']], on='Faculty Name', how='left')

# %%
df4=df1

# %%
merged_df = pd.merge(df1, df2, on='Faculty Name', how='left')

# %%
df1=df4

# %%
df1=df1.drop('Image',axis=1)

# %%
df1.insert(9,'Image',None)

# %%
for i in range(len(df1)):
    faculty_name = df1.loc[i, 'Faculty Name']
    if faculty_name in df2['Faculty Name'].values:
        image_url = df2.loc[df2['Faculty Name'] == faculty_name, 'Image'].values[0]
        df1.loc[i, 'Image'] = image_url

# %%
df1.to_csv('IIT_Gandhinagar.csv',index=False)

# %% [markdown]
# #Combining all three dataset

# %%
import pandas as pd
from ast import literal_eval

# %%
df1=pd.read_csv('/content/IIT_Gandhinagar.csv')
df2=pd.read_csv('/content/IITGoa_Faculty.csv')
df3=pd.read_csv('/content/IITG_Faculty.csv')

# %%
df1=df1.drop('index',axis=1)
df2=df2.drop('index',axis=1)
df3=df3.drop('index',axis=1)

# %%
merged=pd.concat([df1,df2,df3])

# %%
merged.to_csv('final_faculty.csv',index=False)

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet

def find_synonyms(query, interests):
    synonyms = []
    for interest in interests:
        similarity = 0
        for synset in wordnet.synsets(query):
            for lemma in synset.lemmas():
                if interest.lower() in lemma.name().lower():
                    similarity = max(similarity, synset.path_similarity(wordnet.synset(synset.name())))
        synonyms.append((interest, similarity))
    synonyms.sort(key=lambda x: x[1], reverse=True)
    return [s[0] for s in synonyms]

# Example usage
query = 'Adversarial Learning'
interests = ['Machine learning', 'Electrical Engineering']
synonyms = find_synonyms(query, interests)
print(synonyms)
# Out:
# ['Machine learning', 'Electrical Engineering']

# %%
df=df3

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# download necessary NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# read in the dataframe
df = pd.read_csv('final_faculty.csv')

# tokenize each research interest and apply part of speech tagging
df['Research Interests'] = df['Research Interests'].apply(lambda x: word_tokenize(x))
df['Research Interests'] = df['Research Interests'].apply(lambda x: nltk.pos_tag(x))

# define a function to map part of speech tags to WordNet tags
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

# lemmatize each token in the research interest column
df['Research Interests'] = df['Research Interests'].apply(lambda x: [(lemmatizer.lemmatize(word, get_wordnet_pos(tag)) if get_wordnet_pos(tag) else word) for word, tag in x])

# join the tokens back into a string
df['Research Interests'] = df['Research Interests'].apply(lambda x: ' '.join(x))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df.to_csv('/content/IIT_G.csv')

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
 
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
stopWords = set(stopwords.words('english'))
def fun(data):
  words = word_tokenize(data)
  wordsFiltered = []

  for w in words:
      if w not in stopWords:
          wordsFiltered.append(w)
  return  ' '.join(wordsFiltered)

joinedString =fun(data)

print(joinedString)
# Out:
# All work play makes jack dull boy . All work play makes jack dull boy .

# %%
df=pd.read_csv('IIT_G.csv',converters={'Research Interesets':literal_eval})

# %%
(df['Research Interests'][0][3])
# Out:
# 'R'

# %%
import ast

string = "[ 'Role of inflammatory pathway in cancer development ' , ' Identification of novel biomarkers for cancer diagnosis and prognosis ' , ' Cancer drug discovery ' , ' Development of transgenic and gene knockout mouse model for biomedical research . ' ]"
items = 
print(items)
# Out:
# ['Role of inflammatory pathway in cancer development ', ' Identification of novel biomarkers for cancer diagnosis and prognosis ', ' Cancer drug discovery ', ' Development of transgenic and gene knockout mouse model for biomedical research . ']

# %%
ast.literal_eval(df['Research Interests'][0].replace("'", "\""))
# Out:
# ['Role of inflammatory pathway in cancer development ',
#  ' Identification of novel biomarkers for cancer diagnosis and prognosis ',
#  ' Cancer drug discovery ',
#  ' Development of transgenic and gene knockout mouse model for biomedical research . ']

# %%
print(df['Research Interests'][0][0])
# Out:
# Role of inflammatory pathway in cancer development

# %%
fun(df['Research Interests'][0][0])
# Out:
# 'Role inflammatory pathway cancer development'

# %%
for i in range(len(df)):
  curr=[]
  for j in range(len(df['Research Interests'][i])):
    curr.append(fun(df['Research Interests'][i][j]))
  df['Research Interests'][i]=curr
# Out:
# <ipython-input-86-07ef7dfa6ee4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Research Interests'][i]=curr

# %%
df.to_csv('/content/IIT_G.csv',index=False)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

stop_words = set(stopwords.words('english'))

def preprocess(text):
    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove non-alphabetic characters and punctuation marks
    tokens = [token for token in tokens if token.isalpha()]

    # Remove stopwords
    tokens = [token for token in tokens if token.lower() not in stop_words]

    # Lemmatize the tokens
    lemmatizer = nltk.stem.WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens]

    # Join the tokens back into a string
    return ' '.join(tokens)

# %%
import string
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(preprocessor=preprocess)

# join the text in the 'Research Interests' column
text_data = df['Research Interests'].apply(lambda x: ' '.join(x))
print(text_data)

# fit the vectorizer to the text data

vectorizer.fit(text_data)

# transform the text data into TF-IDF vectors
tfidf_vectors = vectorizer.transform(text_data)
# Out:
# 0      Role inflammatory pathway cancer development I...
# 1              Dynamics bimolecular scattering process .
# 2      Nanobiotechnology Chemistry-Biology Interface ...
# 3                              Environmental Engineering
# 4      * Driver behaviour * Traffic flow theory model...
#                              ...
# 154    *  F l  w   n    r  n  p  r    h r  u g h  p  ...
# 155    G r  p h  A l g  r   h    ,  D    r  b u  e   ...
# 156    W   e r  W  v e  M e c h  n  c   ,  R  v e r  ...
# 157    F  n   e  E l e  e n   M e  h    |  R e    u  ...
# 158    *  B e h  v   r   f  u n    u r   e      l   u...
# Name: Research Interests, Length: 159, dtype: object

# %%
df.to_csv('/content/IIT_G.csv',index=False)

# %%
df=df.iloc[:111]

# %%
df.to_csv('/content/IIT_G1.csv',index=False)

# %% [markdown]
# #IIT BHU

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/IITBHU_Faculty - Sheet1.csv')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.insert(5, 'Scholar Url', None)

# %%
# !pip install scholarly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scholarly in /usr/local/lib/python3.9/dist-packages (1.7.11)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.2.13)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.1.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.0.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from scholarly) (2.27.1)
# Requirement already satisfied: selenium in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.9.0)
# Requirement already satisfied: free-proxy in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.1.1)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.5.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from scholarly) (4.11.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/dist-packages (from scholarly) (0.24.0)
# Requirement already satisfied: arrow in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.2.3)
# Requirement already satisfied: bibtexparser in /usr/local/lib/python3.9/dist-packages (from scholarly) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.9/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->scholarly) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.9/dist-packages (from bibtexparser->scholarly) (3.0.9)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->scholarly) (1.14.1)
# Requirement already satisfied: importlib-resources>=5.0 in /usr/local/lib/python3.9/dist-packages (from fake-useragent->scholarly) (5.12.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from free-proxy->scholarly) (4.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (1.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (2022.12.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (3.4)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from httpx->scholarly) (0.17.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.9/dist-packages (from selenium->scholarly) (0.10.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.9/dist-packages (from selenium->scholarly) (0.22.0)
# Requirement already satisfied: sphinxcontrib-jquery!=3.0.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (4.1)
# Requirement already satisfied: sphinx<7,>=1.6 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (3.5.4)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.9/dist-packages (from sphinx-rtd-theme->scholarly) (0.16)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (3.6.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (0.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=5.0->fake-useragent->scholarly) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (23.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.1.5)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.4)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.14.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.12.1)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (67.6.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (0.7.13)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.0.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.9/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (3.1.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (23.1.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.10)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.9/dist-packages (from trio~=0.17->selenium->scholarly) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.9/dist-packages (from trio-websocket~=0.9->selenium->scholarly) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.3->sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.1.2)

# %%
from scholarly import scholarly
def get_google_scholar_url(name,institution):
    search_query = scholarly.search_author(f'{name} {institution}')
    author = next(search_query, None)

    if author is None:
        return None
    return "https://scholar.google.co.in/citations?user="+author['scholar_id']

# %%
faculty_names=df['Faculty Name']
for i in range(len(df)):
  if(df['Scholar Url'][i]==None):
    institution= 'IIT BHU'
    answer=get_google_scholar_url(" ".join(faculty_names[i].split()[1:3]),institution)
    print('ans:',answer)
    if answer==None:
      print(faculty_names[i])
      institution='Indian Institute of Technology BHU'
      answer=get_google_scholar_url(" ".join(faculty_names[i].split()[1:3]),institution)
      print(answer)
    df['Scholar Url'][i]=answer
# Out:
# ans: https://scholar.google.co.in/citations?user=rwkjkgcAAAAJ
# ans: None
# Dr. Parthasarathi Chakrabarti
# None
# ans: https://scholar.google.co.in/citations?user=cYritM0AAAAJ
# ans: https://scholar.google.co.in/citations?user=6LvL9aEAAAAJ
# ans: None
# Dr. Vishwambhar Nath Mishra
# None
# ans: https://scholar.google.co.in/citations?user=mUCM_A4AAAAJ
# ans: https://scholar.google.co.in/citations?user=2RVpcw0AAAAJ
# ans: None
# Dr. M. Thottappan
# https://scholar.google.co.in/citations?user=WoYMyGwAAAAJ
# ans: None
# Dr. Navin Singh Rajput
# None
# ans: https://scholar.google.co.in/citations?user=V9tW7pIAAAAJ
# ans: https://scholar.google.co.in/citations?user=3GajpTwAAAAJ
# ans: https://scholar.google.co.in/citations?user=MIkCVeEAAAAJ
# ans: https://scholar.google.co.in/citations?user=rwkjkgcAAAAJ
# ans: https://scholar.google.co.in/citations?user=2lVVYf8AAAAJ
# ans: None
# Dr. Oppili Prasad L
# None
# ans: None
# Dr. Priya Ranjan Muduli
# None
# ans: None
# Dr. Kishor P. Sarawadekar
# None
# ans: https://scholar.google.co.in/citations?user=ajfz17IAAAAJ
# ans: https://scholar.google.co.in/citations?user=pyB8nJcAAAAJ
# ans: None
# Dr. Smrity Dwivedi
# None
# ans: https://scholar.google.co.in/citations?user=tTAzKj0AAAAJ
# ans: https://scholar.google.co.in/citations?user=HBgXg-UAAAAJ
# ans: https://scholar.google.co.in/citations?user=U-Vn2y4AAAAJ
# ans: None
# Dr. Arakere Puttaswamy Harsha
# None
# ans: None
# Dr. Jahar Sarkar
# https://scholar.google.co.in/citations?user=Tv8978gAAAAJ
# ans: None
# Dr. Kripa Sanker Tripathi
# None
# ans: None
# Dr. Prabhash Bhardwaj
# None
# ans: None
# Dr. Prashant Shukla
# None
# ans: https://scholar.google.co.in/citations?user=z9sV09AAAAAJ
# ans: https://scholar.google.co.in/citations?user=NSsJ-7gAAAAJ
# ans: None
# Dr. Rajnesh Tyagi
# https://scholar.google.co.in/citations?user=ecXzceoAAAAJ
# ans: https://scholar.google.co.in/citations?user=bpI8qEcAAAAJ
# ans: https://scholar.google.co.in/citations?user=bcJeyYgAAAAJ
# ans: https://scholar.google.co.in/citations?user=LCD74DIAAAAJ
# ans: https://scholar.google.co.in/citations?user=pxdk-dkAAAAJ
# ans: None
# Dr. Saroja Kanta Panda
# None
# ans: https://scholar.google.co.in/citations?user=oIPsKLoAAAAJ
# ans: None
# Dr. Amit Tyagi
# None
# ans: https://scholar.google.co.in/citations?user=5VZCiMUAAAAJ
# ans: https://scholar.google.co.in/citations?user=IIznVdkAAAAJ
# ans: None
# Dr. Debashis Khan
# None
# ans: None
# Dr. Jeevan Vachan Tirkey
# None
# ans: https://scholar.google.co.in/citations?user=SlNIyDUAAAAJ
# ans: None
# Dr. Meghanshu Vashista
# None
# ans: https://scholar.google.co.in/citations?user=iUNbKhIAAAAJ
# ans: https://scholar.google.co.in/citations?user=HkCaUZYAAAAJ
# ans: https://scholar.google.co.in/citations?user=52t8jDcAAAAJ
# ans: https://scholar.google.co.in/citations?user=JgUm8MkAAAAJ
# ans: None
# Dr. Swasti Sundar Mondal
# None
# ans: None
# Dr. Uppu Srinivas Rao
# None
# ans: None
# Dr. B. Nageswara Sarma
# None
# ans: None
# Dr. Kamalesh Kumar Singh
# None
# ans: None
# Dr. N.C. Santhi Srinivas
# None
# ans: None
# Dr. Nilay Krishna Mukhopadhyay
# None
# ans: None
# Dr. Rajiv Kumar Mandal
# None
# ans: https://scholar.google.co.in/citations?user=T3ENK38AAAAJ
# ans: https://scholar.google.co.in/citations?user=pxhyr2IAAAAJ
# ans: None
# Dr. Chhail Kumar Behera
# None
# ans: https://scholar.google.co.in/citations?user=zl0ccxUAAAAJ
# ans: None
# Dr. Jayant Kumar Singh
# None

# %%
import numpy as np
df=df.replace(to_replace='None', value=np.nan).dropna()

# %%
df.insert(6, 'h_index', None)
df.insert(7, 'i10_index', None)
df=df.reset_index()

# %%
from bs4 import BeautifulSoup
import urllib.request
def get_h_and_i(url):
  page = urllib.request.urlopen(url)
  soup = BeautifulSoup(page, 'html.parser') 
  indexes = soup.find_all("td", "gsc_rsb_std")
  if len(indexes)>0:
    h_index = indexes[2].string
    i10_index = indexes[4].string
    return h_index,i10_index
  return 0,0
for i in range(len(df)):
  if(type(df['Scholar Url'][i])!=float):
    df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
for i in range(len(df)):
  df['h_index'][i]=int(df['h_index'][i][0])
  df['i10_index'][i]=int(df['i10_index'][i][0])
# Out:
# <ipython-input-71-ed6949983c23>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
# <ipython-input-71-ed6949983c23>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i]=int(df['h_index'][i][0])
# <ipython-input-71-ed6949983c23>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['i10_index'][i]=int(df['i10_index'][i][0])

# %%
df.to_csv('IIT_BHU.csv',index=False)

# %%
df
# Out:
# index                   0
# Institution             0
# Faculty Name            0
# Field                   0
# HomePage                0
# Reasearch Interests     0
# Scholar Url            25
# h_index                59
# i10_index              59
# Image                   0
# dtype: int64

# %%
def removeDuplicates(lst):
     
    return [[a, b] for i, [a, b] in enumerate(lst)
    if not any(c == b for _, c in lst[:i])]

# %%
arr=[('Abhishek Bichhawat', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/abhishek', 'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'), ('Rajat Moona', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/rajat-moona', 'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'), ('Sameer Gundurao Kulkarni', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/sameer', 'https://scholar.google.co.in/citations?user=2QGvuwIAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/sameer/98771858-1679554159/sameer.jpg'), ('Vimal Mishra', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/earths/fac-vimal', 'https://scholar.google.co.in/citations?user=wq7CgpUAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/civil/fac-vimal/2766794975-1679554160/1vimal.jpg'), ('Abhishek Bichhawat', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/abhishek', 'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg', ([12.84466197, 10.63456713, 12.84466197, 12.84466197, 12.84466197,
       10.63456713, 12.03331164, 12.84466197, 10.63456713]))]

# %%
arr
# Out:
# [('Abhishek Bichhawat',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/abhishek',
#   'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'),
#  ('Rajat Moona',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/rajat-moona',
#   'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'),
#  ('Sameer Gundurao Kulkarni',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/sameer',
#   'https://scholar.google.co.in/citations?user=2QGvuwIAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/sameer/98771858-1679554159/sameer.jpg'),
#  ('Vimal Mishra',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/earths/fac-vimal',
#   'https://scholar.google.co.in/citations?user=wq7CgpUAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/civil/fac-vimal/2766794975-1679554160/1vimal.jpg'),
#  ('Abhishek Bichhawat',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/abhishek',
#   'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg',
#   [12.84466197,
#    10.63456713,
#    12.84466197,
#    12.84466197,
#    12.84466197,
#    10.63456713,
#    12.03331164,
#    12.84466197,
#    10.63456713])]

# %%
unique_arr = [t for i, t in enumerate(arr) if t not in arr[i:]]

# %%
unique_arr
# Out:
# [('Abhishek Bichhawat',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/abhishek',
#   'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'),
#  ('Rajat Moona',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/rajat-moona',
#   'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'),
#  ('Sameer Gundurao Kulkarni',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/sameer',
#   'https://scholar.google.co.in/citations?user=2QGvuwIAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/sameer/98771858-1679554159/sameer.jpg'),
#  ('Vimal Mishra',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/earths/fac-vimal',
#   'https://scholar.google.co.in/citations?user=wq7CgpUAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/civil/fac-vimal/2766794975-1679554160/1vimal.jpg'),
#  ('Abhishek Bichhawat',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/abhishek',
#   'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg',
#   [12.84466197,
#    10.63456713,
#    12.84466197,
#    12.84466197,
#    12.84466197,
#    10.63456713,
#    12.03331164,
#    12.84466197,
#    10.63456713])]

# %%
res = [arr[i] for i in range(len(arr)-1) if arr[i][0] not in arr[i+1:][0] for j in range(i+1,len(arr))]
print("The list after removing duplicates:", res)
# Out:
# The list after removing duplicates: [('Abhishek Bichhawat', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/abhishek', 'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'), ('Abhishek Bichhawat', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/abhishek', 'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'), ('Abhishek Bichhawat', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/abhishek', 'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'), ('Abhishek Bichhawat', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/abhishek', 'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'), ('Rajat Moona', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/rajat-moona', 'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'), ('Rajat Moona', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/rajat-moona', 'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'), ('Rajat Moona', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/rajat-moona', 'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'), ('Sameer Gundurao Kulkarni', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/sameer', 'https://scholar.google.co.in/citations?user=2QGvuwIAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/sameer/98771858-1679554159/sameer.jpg'), ('Sameer Gundurao Kulkarni', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/cse/sameer', 'https://scholar.google.co.in/citations?user=2QGvuwIAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/cse/sameer/98771858-1679554159/sameer.jpg'), ('Vimal Mishra', 'Indian Institute of Technology Gandhinagar', 'https://iitgn.ac.in/faculty/earths/fac-vimal', 'https://scholar.google.co.in/citations?user=wq7CgpUAAAAJ', 'https://iitgn.ac.in/media/pages/faculty/civil/fac-vimal/2766794975-1679554160/1vimal.jpg')]

# %%
for i in range(len(arr)):
  for j in range(i+1,len(arr)):
    if arr[i][0]==arr[j][0]:
      arr.pop(j)
# Out:
# Abhishek Bichhawat Rajat Moona
# Abhishek Bichhawat Sameer Gundurao Kulkarni
# Abhishek Bichhawat Vimal Mishra
# Abhishek Bichhawat Abhishek Bichhawat
# hi
# Rajat Moona Sameer Gundurao Kulkarni
# Rajat Moona Vimal Mishra
# Sameer Gundurao Kulkarni Vimal Mishra

# %%
arr
# Out:
# [('Abhishek Bichhawat',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/abhishek',
#   'https://scholar.google.co.in/citations?user=qJavKW4AAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/abhishek/962353777-1679554159/avhishek.jpg'),
#  ('Rajat Moona',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/rajat-moona',
#   'https://scholar.google.co.in/citations?user=jKAw8-sAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/rajat-moona/2905206850-1679554159/rajat-moona.jpg'),
#  ('Sameer Gundurao Kulkarni',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/cse/sameer',
#   'https://scholar.google.co.in/citations?user=2QGvuwIAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/cse/sameer/98771858-1679554159/sameer.jpg'),
#  ('Vimal Mishra',
#   'Indian Institute of Technology Gandhinagar',
#   'https://iitgn.ac.in/faculty/earths/fac-vimal',
#   'https://scholar.google.co.in/citations?user=wq7CgpUAAAAJ',
#   'https://iitgn.ac.in/media/pages/faculty/civil/fac-vimal/2766794975-1679554160/1vimal.jpg')]

# %% [markdown]
# # IIT Bombay CSE

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/IITB_cse_Profs.csv')

# %%
df
# Out:
#                                     Faculty Name  \
# 0                                 Bharat G Adsul
# 1                                    Varsha Apte
# 2                                      Kavi Arya
# 3                                 Suyash P Awate
# 4                                   Umesh Bellur
# 5                         Pushpak P Bhattacharya
# 6                                    Sujoy Bhore
# 7                             Soumen Chakrabarti
# 8                           Supratik Chakraborty
# 9                                Sharat Chandran
# 10                         Parag Kumar Chaudhuri
# 11  Siddhartha Chaudhuri On Extra Ordinary Leave
# 12                            Kameswari Chebrolu
# 13                                     Om Damani
# 14                                       Abir De
# 15                                  Ajit A Diwan
# 16        Ashwin Gumaste On Extra Ordinary Leave
# 17                                Ashutosh Gupta
# 18                                  Rohit Gurjar
# 19                             Rushikesh K Joshi
# 20                                Preethi Jyothi
# 21                      Shivaram Kalyanakrishnan
# 22                                  Uday Khedker
# 23                          Purushottam Kulkarni
# 24                                   Akash Kumar
# 25                                  Nutan Limaye
# 26                               Bernard Menezes
# 27                     Krishna Shankar Narayanan
# 28                                 Swaprava Nath
# 29                             Biswabandan Panda
# 30                             Manoj Prabhakaran
# 31                                  Ajit Rajwade
# 32                               Bhaskaran Raman
# 33                            Ganesh Ramkrishnan
# 34                                Abhiram Ranade
# 35                          Vinay Joseph Ribeiro
# 36                                      Akshay S
# 37                             Amitabha A Sanyal
# 38                               Sunita Sarawagi
# 39                                   G Sivakumar
# 40                               Milind A Sohoni
# 41                                   S Sudarshan
# 42                                  Manas Thakur
# 43                  Saisundararaman Vishwanathan
# 44                              Mythili Vutukuru
#
#                                              HomePage  \
# 0                  https://www.cse.iitb.ac.in/~adsul/
# 1                 https://www.cse.iitb.ac.in/~varsha/
# 2                   https://www.cse.iitb.ac.in/~kavi/
# 3                 https://www.cse.iitb.ac.in/~suyash/
# 4                  https://www.cse.iitb.ac.in/~umesh/
# 5                     https://www.cse.iitb.ac.in/~pb/
# 6   https://sites.google.com/view/homepage-of-sujo...
# 7                 https://www.cse.iitb.ac.in/~soumen/
# 8               https://www.cse.iitb.ac.in/~supratik/
# 9                 https://www.cse.iitb.ac.in/~sharat/
# 10                https://www.cse.iitb.ac.in/~paragc/
# 11                 https://www.cse.iitb.ac.in/~sidch/
# 12              https://www.cse.iitb.ac.in/~chebrolu/
# 13                https://www.cse.iitb.ac.in/~damani/
# 14                  https://www.cse.iitb.ac.in/~abir/
# 15                   https://www.cse.iitb.ac.in/~aad/
# 16                https://www.cse.iitb.ac.in/~ashwin/
# 17                   https://www.cse.iitb.ac.in/~akg/
# 18               https://www.cse.iitb.ac.in/~rgurjar/
# 19                   https://www.cse.iitb.ac.in/~rkj/
# 20               https://www.cse.iitb.ac.in/~pjyothi/
# 21              https://www.cse.iitb.ac.in/~shivaram/
# 22                  https://www.cse.iitb.ac.in/~uday/
# 23                  https://www.cse.iitb.ac.in/~puru/
# 24                 https://www.cse.iitb.ac.in/~akash/
# 25                 https://www.cse.iitb.ac.in/~nutan/
# 26               https://www.cse.iitb.ac.in/~bernard/
# 34  https://www.cse.iitb.ac.in/images/faculty/rana...
# 35  https://www.cse.iitb.ac.in/images/faculty/vina...
# 36  https://www.cse.iitb.ac.in/images/faculty/aksh...
# 37   https://www.cse.iitb.ac.in/images/faculty/as.jpg
# 38  https://www.cse.iitb.ac.in/images/faculty/suni...
# 39  https://www.cse.iitb.ac.in/images/faculty/siva...
# 40  https://www.cse.iitb.ac.in/images/faculty/soho...
# 41  https://www.cse.iitb.ac.in/images/faculty/suda...
# 42  https://www.cse.iitb.ac.in/images/faculty/mana...
# 43  https://www.cse.iitb.ac.in/images/faculty/sund...
# 44  https://www.cse.iitb.ac.in/images/faculty/myth...
#
#                                    Research Interests  \
# 0   Formal methods in Concurrency, Logics and Game...
# 1   Performance Evaluation of Computer Systems and...
# 2   Functional Programming Applications (Domain Sp...
# 3   Image Analysis, Medical Image Computing, Machi...
# 4   Adaptive Service Orientation, Managing virtual...
# 5   Natural Language Processing, Machine Learning,...
# 6   Computational Geometry, Algorithms, Graph Theo...
# 7                    Hypertext databases, Data mining
# 8   Formal techniques for analysis, verification, ...
# 9   Medical Imaging & Health Informatics, Graphics...
# 10  Animation, Computer Graphics, Virtual and Augm...
# 11  Computational design tools, high-level shape u...
# 12  Architecture and protocol design in wired, wir...
# 13  Program Derivation, Large Scale Systems, Techn...
# 14                Machine learning on graphs and sets
# 15           Algorithms, Theoretical Computer Science
# 16   SDN, NFV, Network Architecture, Carrier Ethernet
# 17  Formal verification: building model checkers f...
# 18  Computational Complexity, Derandomization and ...
# 19  Object Oriented Systems, Distributed Systems, ...
# 20    Machine learning applied to speech and language
# 21  Reinforcement Learning, Humanoid Robotics & Ro...
# 22  Programming Languages, Compilers, Data Flow An...
# 23  Operating systems, Virtualization, Cloud Compu...
# 24  Spectral Graph Theory, Planar graph Algorithms...
# 25                   Algorithms and Complexity Theory
# 26  Information Appliances, Electronic Commerce, J...
# 27  Formal Methods, Analysis of Concurrent program...
# 28  Game Theory, Computational Mechanism Design, C...
# 29  Computer Architecture for Performance and Secu...
# 30         Cryptography, Theoretical Computer Science
# 31  Image Processing, Computer Vision, Image Resto...
# 32  Computer networks, Wireless systems, Communica...
# 33  Human assisted AI/ML, AI/ML in resource constr...
# 34          Algorithms and Combinatorial Optimization
# 35  Computer and Network Security (blockchain, int...
# 36                                     Formal methods
# 37  Functional Programming, Compilers, and Program...
# 38  Machine Learning, Databases, Data mining, and ...
# 39  Automated Reasoning, Logic Programming, Rewrit...
# 40  Combinatorial Optimization, Mathematical Progr...
# 41  Query processing and optimization, Keyword que...
# 42  Program analysis, compiler optimizations, para...
# 43       Algorithms, Combinatorics, Complexity Theory
# 44                             Networking and Systems
#
#                                           Scholar Url
# 0   https://scholar.google.co.in/citations?user=bZ...
# 1   https://scholar.google.co.in/citations?user=g2...
# 2   https://scholar.google.co.in/citations?user=Qz...
# 3   https://scholar.google.co.in/citations?user=xV...
# 4   https://scholar.google.co.in/citations?user=Wn...
# 5   https://scholar.google.co.in/citations?user=vv...
# 6   https://scholar.google.co.il/citations?user=94...
# 7   https://scholar.google.com/citations?user=LfF2...
# 8   https://scholar.google.co.in/citations?user=Lw...
# 9   https://scholar.google.co.in/citations?user=pR...
# 10  https://scholar.google.co.in/citations?user=kO...
# 11                                                NaN
# 12  https://scholar.google.co.in/citations?user=U-...
# 13  https://scholar.google.co.in/citations?user=oE...
# 14  https://scholar.google.co.in/citations?user=_9...
# 15  https://scholar.google.co.in/citations?user=Xp...
# 16  https://www.cse.iitb.ac.in/~gnl/publications.html
# 17                                                NaN
# 18  https://scholar.google.com/citations?user=dtbK...
# 19  https://scholar.google.co.in/citations?user=zm...
# 20  https://scholar.google.com/citations?user=QN_u...
# 21  https://scholar.google.co.in/citations?user=YZ...
# 22  https://scholar.google.co.in/citations?hl=en&u...
# 23  https://scholar.google.co.in/citations?user=Gs...
# 24  https://scholar.google.ca/citations?user=L358D...
# 25  https://scholar.google.co.in/citations?user=r8...
# 26  https://scholar.google.co.in/citations?user=He...
# 27  https://scholar.google.co.in/citations?user=14...
# 28  https://scholar.google.co.in/citations?user=Tl...
# 29  https://scholar.google.co.in/citations?user=ZG...
# 30  https://scholar.google.com/citations?user=FANR...
# 31  https://scholar.google.co.in/citations?user=Ck...
# 32  https://scholar.google.co.in/citations?user=qj...
# 33  https://scholar.google.co.in/citations?user=W1...
# 34  https://scholar.google.co.in/citations?user=lb...
# 35  https://scholar.google.co.uk/citations?user=Xx...
# 36  https://scholar.google.co.in/citations?user=0X...
# 37                                                NaN
# 38  https://scholar.google.co.in/citations?user=Hg...
# 39  https://scholar.google.co.in/citations?user=gq...
# 40                                                NaN
# 41  https://scholar.google.com/citations?user=KtP9...
# 42  https://scholar.google.com/citations?user=4DCf...
# 43  https://scholar.google.co.in/citations?user=8C...
# 44  https://scholar.google.co.in/citations?user=-O...

# %%
for i in range(len(df)):
  df['Research Interests'][i]=df['Research Interests'][i].split(',')

# %%
df=df.dropna()

# %%
df=df.reset_index()

# %%
df.insert(5, 'h_index', None)
df.insert(6, 'i10_index', None)

# %%
from bs4 import BeautifulSoup
import urllib.request
def get_h_and_i(url):
  try:
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, 'html.parser') 
    indexes = soup.find_all("td", "gsc_rsb_std")
    if len(indexes)>0:
      h_index = indexes[2].string
      i10_index = indexes[4].string
      return h_index,i10_index

  except:
      return 0,0
  return 0,0
for i in range(len(df)):
  if(type(df['Scholar Url'][i])!=float):
    df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
for i in range(len(df)):
  df['h_index'][i]=int(df['h_index'][i][0])
  df['i10_index'][i]=int(df['i10_index'][i][0])
# Out:
# <ipython-input-165-e2facf2e0dca>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i],df['i10_index'][i]=zip(get_h_and_i(df['Scholar Url'][i]))
# <ipython-input-165-e2facf2e0dca>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h_index'][i]=int(df['h_index'][i][0])
# <ipython-input-165-e2facf2e0dca>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['i10_index'][i]=int(df['i10_index'][i][0])

# %%
df.to_csv('IITB_CSE.csv',index=False)
